# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import stats
from scipy.stats import norm
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('abalone.csv',header=None, names =['Sex', 'Length', 'Diameter', 'Height',
'Whole weight', 'Shucked weight', 'Viscera weight', 'Shell weight', 'Rings'])

# %%
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
df.tail()
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12

# %%
df.shape
# Out:
# (4177, 9)

# %%
df.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
# Sex               4177 non-null object
# Length            4177 non-null float64
# Diameter          4177 non-null float64
# Height            4177 non-null float64
# Whole weight      4177 non-null float64
# Shucked weight    4177 non-null float64
# Viscera weight    4177 non-null float64
# Shell weight      4177 non-null float64
# Rings             4177 non-null int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
df.skew()
# Out:
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# dtype: float64

# %%
df.var()
# Out:
# Length             0.014422
# Diameter           0.009849
# Height             0.001750
# Whole weight       0.240481
# Shucked weight     0.049268
# Viscera weight     0.012015
# Shell weight       0.019377
# Rings             10.395266
# dtype: float64

# %%
import pandas_profiling as pp
pp.ProfileReport(df)
# Out:
# ...
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.

# %% [markdown]
# ### Data visualization

# %%
#histogram
sns.distplot(df['Rings']);

# %%
#scatter plot Length/Rings
var = 'Length'
data = pd.concat([df['Rings'], df[var]], axis=1)
data.plot.scatter(x=var, y='Rings');

# %%
var = 'Diameter'
data = pd.concat([df['Rings'],df[var]],axis=1)
data.plot.scatter(x=var,y='Rings')

# %%
var = 'Height'
data = pd.concat([df['Rings'],df[var]],axis=1)
data.plot.scatter(x=var,y='Rings')

# %%
var ='Whole_weight'
data=pd.concat([df['Rings'],df[var]],axis=1)
data.plot.scatter(x=var,y='Rings')

# %%
#scatter plot Length/Rings
var = 'Length'
data = pd.concat([df['Rings'], df[var]], axis=1)
data.plot.scatter(x=var, y='Rings');

# %%
sns.FacetGrid(df,hue='Sex',size=5).map(sns.distplot,'Length').add_legend();
plt.show();

# %%
sns.FacetGrid(df,hue='Sex',size=5).map(sns.distplot,'Diameter').add_legend();

# %%
sns.FacetGrid(df,hue='Sex',size=5).map(sns.distplot,'Height').add_legend();
plt.show();

# %%
sns.boxplot(x='Sex',y='Length',data=df)
plt.show();

# %%
sns.boxplot(x='Sex',y='Diameter',data=df)
plt.show();

# %%
sns.FacetGrid(df,hue='Sex',size=5).map(plt.scatter,'Length','Diameter').add_legend();
plt.show();

# %%
sns.FacetGrid(df,hue='Sex',size=5).map(plt.scatter,'Whole_weight','Shucked_weight').add_legend();
plt.show();

# %%
sns.FacetGrid(df,hue='Sex',size=5).map(plt.scatter,'Height','Shell_weight').add_legend();
plt.show();

# %%
fig,ax2 = plt.subplots(4,2, figsize=(16,16))
sns.distplot(df['Length'],ax=ax2[0][0])
sns.distplot(df['Diameter'],ax=ax2[0][1])
sns.distplot(df['Height'],ax=ax2[1][0])
sns.distplot(df['Whole_weight'],ax=ax2[1][1])
sns.distplot(df['Shucked_weight'],ax=ax2[2][0])
sns.distplot(df['Viscera_weight'],ax=ax2[2][1])
sns.distplot(df['Shell_weight'],ax=ax2[3][0])

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole_weight', 'Shucked_weight',
#        'Viscera_weight', 'Shell_weight', 'Rings'],
#       dtype='object')

# %%
# Categorical vs Continuous ---- Outcome vs Glucose 

fig, ax2 = plt.subplots(2, 2, figsize=(12, 8))
sns.boxplot(x="Sex", y="Length", data=df,ax=ax2[0][0])
sns.barplot(df['Sex'], df['Length'],ax=ax2[0][1])
sns.stripplot(df['Sex'],df['Length'], jitter=True,ax=ax2[1][0])
sns.swarmplot(df['Sex'], df['Length'], ax=ax2[1][1])

# %%
fig, ax2 = plt.subplots(2, 2, figsize=(12, 8))
sns.boxplot(x="Sex", y="Diameter", data=df,ax=ax2[0][0])
sns.barplot(df['Sex'], df['Diameter'],ax=ax2[0][1])
sns.stripplot(df['Sex'],df['Diameter'], jitter=True,ax=ax2[1][0])
sns.swarmplot(df['Sex'], df['Diameter'], ax=ax2[1][1])

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole_weight', 'Shucked_weight',
#        'Viscera_weight', 'Shell_weight', 'Rings'],
#       dtype='object')

# %%
fig, ax2 = plt.subplots(2, 2, figsize=(12, 8))
sns.boxplot(x="Sex", y="Height", data=df,ax=ax2[0][0])
sns.barplot(df['Sex'], df['Height'],ax=ax2[0][1])
sns.stripplot(df['Sex'],df['Height'], jitter=True,ax=ax2[1][0])
sns.swarmplot(df['Sex'], df['Height'], ax=ax2[1][1])

# %%
fig, ax2 = plt.subplots(2,2,figsize=(12,8))
sns.boxplot(x="Sex",y="Whole_weight",data=df,ax=ax2[0][0])
sns.barplot(df["Sex"],df["Whole_weight"], ax=ax2[0][1])
sns.stripplot(df["Sex"],df['Whole_weight'],jitter=True,ax=ax2[1][0])
sns.swarmplot(df["Sex"],df["Whole_weight"],ax=ax2[1][1])

# %%
fig, ax2 = plt.subplots(2,2,figsize=(12,8))
sns.boxplot(x="Sex",y="Shucked_weight",data=df,ax=ax2[0][0])
sns.barplot(df["Sex"],df["Shucked_weight"], ax=ax2[0][1])
sns.stripplot(df["Sex"],df['Shucked_weight'],jitter=True,ax=ax2[1][0])
sns.swarmplot(df["Sex"],df["Shucked_weight"],ax=ax2[1][1])

# %%
fig, ax2 = plt.subplots(2,2,figsize=(12,8))
sns.boxplot(x="Rings",y="Shucked_weight",data=df,ax=ax2[0][0])
sns.barplot(df["Rings"],df["Shucked_weight"], ax=ax2[0][1])
sns.stripplot(df["Rings"],df['Shucked_weight'],jitter=True,ax=ax2[1][0])
sns.swarmplot(df["Rings"],df["Shucked_weight"],ax=ax2[1][1])

# %%
fig, ax2 = plt.subplots(2, 2, figsize=(12, 8))
sns.boxplot(x="Rings", y="Length", data=df,ax=ax2[0][0])
sns.barplot(df['Rings'], df['Length'],ax=ax2[0][1])
sns.stripplot(df['Rings'],df['Length'], jitter=True,ax=ax2[1][0])
sns.swarmplot(df['Rings'], df['Length'], ax=ax2[1][1])

# %%
fig, ax2 = plt.subplots(2, 2, figsize=(12, 8))
sns.boxplot(x="Rings", y="Diameter", data=df,ax=ax2[0][0])
sns.barplot(df['Rings'], df['Diameter'],ax=ax2[0][1])
sns.stripplot(df['Rings'],df['Diameter'], jitter=True,ax=ax2[1][0])
sns.swarmplot(df['Rings'], df['Diameter'], ax=ax2[1][1])

# %%
fig, ax2 = plt.subplots(2, 2, figsize=(12, 8))
sns.boxplot(x="Rings", y="Height", data=df,ax=ax2[0][0])
sns.barplot(df['Rings'], df['Height'],ax=ax2[0][1])
sns.stripplot(df['Rings'],df['Height'], jitter=True,ax=ax2[1][0])
sns.swarmplot(df['Rings'], df['Height'], ax=ax2[1][1])

# %%
# corrlation matrix
cor= df.corr()
cor
# Out:
#                   Length  Diameter    Height  Whole_weight  Shucked_weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole_weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked_weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera_weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell_weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera_weight  Shell_weight     Rings
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole_weight          0.966375      0.955355  0.540390
# ...

# %%
sns.heatmap(cor,annot=True)

# %%
df.corr().Rings.sort_values(ascending=False)
# Out:
# Rings             1.000000
# Shell_weight      0.627574
# Diameter          0.574660
# Height            0.557467
# Length            0.556720
# Whole_weight      0.540390
# Viscera_weight    0.503819
# Shucked_weight    0.420884
# Name: Rings, dtype: float64

# %% [markdown]
# ## Outliers

# %%
ig=plt.figure(figsize=(20,3))

for i in np.arange(1,8):
    data3=plt.subplot(1,8,i,title=df.columns[i])
    sns.boxplot(df[df.columns[i]])

# %%
df.hist(figsize=(15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000000152C1470>,
# ...
#       dtype=object)

# %%
sns.pairplot(df,size=7,aspect=0.7,kind='reg')

# %% [markdown]
# ## Handling the Missing Values

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### Observation(s):

# %% [markdown]
# It shows that there are no null values (missing values) in the dataset. But, it does not make sense. It seems very likely that zero values encode missing data.We replace 0 by NaN values to count the missing values.

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole_weight      0
# Shucked_weight    0
# Viscera_weight    0
# Shell_weight      0
# Rings             0
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
#Replace 0 with NaN

# %%
#Replace 0 to NaN
df[['Height']]=df[['Height']].replace(0,np.nan)
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
#find the number of missing values
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            2
# Whole_weight      0
# Shucked_weight    0
# Viscera_weight    0
# Shell_weight      0
# Rings             0
# dtype: int64

# %%
df.isnull().sum()/len(df)*100
# Out:
# Sex               0.000000
# Length            0.000000
# Diameter          0.000000
# Height            0.047881
# Whole_weight      0.000000
# Shucked_weight    0.000000
# Viscera_weight    0.000000
# Shell_weight      0.000000
# Rings             0.000000
# dtype: float64

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            2
# Whole_weight      0
# Shucked_weight    0
# Viscera_weight    0
# Shell_weight      0
# Rings             0
# dtype: int64

# %%
df.isnull().values.any()
# Out:
# True

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='winter_r')

# %%
df['Height'].fillna(df['Height'].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole_weight      0
# Shucked_weight    0
# Viscera_weight    0
# Shell_weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# ### Converting Categorical feature

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
df['Sex']=le.fit_transform(df['Sex'])
df.head()
# Out:
#    Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera_weight  Shell_weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7

# %% [markdown]
# ### Removing Outliers

# %%
from scipy.stats import zscore
z_score=abs(zscore(df))
print(df.shape)
data=df[(z_score<3).all(axis=1)]
print(data.shape)
# Out:
# (4177, 9)
# (4029, 9)

# %%
x=data.drop(['Rings'],axis=1)
y=data['Rings']

# %%
x.shape
# Out:
# (4029, 8)

# %%
y.shape
# Out:
# (4029,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
x=sc.fit_transform(x)
x=sc.transform(x)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.20)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR

# %%
def maxr2_score(regr,x,y):
    max_r_score=0
    for r_state in range(35,150):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        reg=linear_model.LinearRegression()
        reg.fit(x_train,y_train)
        y_pred=reg.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to", final_r_state, "is",max_r_score)        
    return final_r_state

# %%
model=[RandomForestRegressor(),DecisionTreeRegressor()]

# %%
knr=KNeighborsRegressor()
r_state=maxr2_score(knr,x,y)
# Out:
# max r2 score corresponding to 103 is 0.5654897851270366

# %%
rfr=RandomForestRegressor()
r_state=maxr2_score(rfr,x,y)
# Out:
# max r2 score corresponding to 103 is 0.5654897851270366

# %%
from sklearn.linear_model import Ridge

# %%
ridge_mod = Ridge(alpha=0.01, normalize=True)
ridge_mod.fit(x_train, y_train)
ridge_mod.fit(x_test, y_test)
ridge_model_pred = ridge_mod.predict(x_test)
ridge_mod.score(x_train, y_train)
# Out:
# 0.5018701349067689

# %%
ridge_mod.score(x_test, y_test)
# Out:
# 0.5180906659155404

# %%
plt.scatter(y_test, ridge_model_pred)
plt.xlabel('True Values')
plt.ylabel('Predictions')
# Out:
# Text(0, 0.5, 'Predictions')

# %%
svr = SVR(kernel = 'linear')
svr.fit(x_train, y_train)
svr.fit(x_test, y_test)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#     gamma='auto_deprecated', kernel='linear', max_iter=-1, shrinking=True,
#     tol=0.001, verbose=False)

# %%
# Hyperparameter Tuning using GridSearchCV

from sklearn.model_selection import  GridSearchCV
param  = {'alpha':[0.01, 0.1, 1,10,100],
         'solver' : ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']}
glrm0 = GridSearchCV(estimator = Ridge(random_state=10,),
param_grid = param,scoring= 'r2' ,cv = 5,  n_jobs = -1)
glrm0.fit(x_train, y_train)
glrm0.best_params_, glrm0.best_score_
glrm0 =glrm0.fit(x_train,y_train)

# %%
glrm0 =glrm0.fit(x_train,y_train)

# %%
ar2 =glrm0.best_score_

# %%
ar2
# Out:
# 0.5043380872174071

# %%
import pickle
#save the traind model
saved_model=pickle.dumps(knr)
#Load the pickel data
DT_from_pickle=pickle.loads(saved_model)
